# %%
import os
import json
from flask import Flask
from flask import Markup
from flask import Flask
from flask import render_template
from flask import request
from flask import redirect, url_for
from flask_sqlalchemy import SQLAlchemy
from sqlalchemy import desc
from operator import itemgetter
from flask import make_response
import time
import re
from bs4 import BeautifulSoup
app = Flask(__name__)

cwd = os.getcwd()
print(cwd)
app.config['SQLALCHEMY_DATABASE_URI'] = "mysql://b035b77bab684d:a3eb18a6@us-cdbr-iron-east-01.cleardb.net/heroku_2acdbf1c6f4647d" #'sqlite:///'+cwd+'/resources/data.db'
db = SQLAlchemy(app)


from models import *
# Out:
# /Users/mac/Desktop/HCISoft/chinise/server
# /usr/local/lib/python3.6/site-packages/flask_sqlalchemy/__init__.py:794: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '
# /Users/mac/Desktop/HCISoft/chinise/server

# %%
# try:
#     # files = []

#     # domain_id = Domain(url=base_url)
#     keywords = Keyword.query.all()
#     # print(keywords)
#     for (dirpath, dirnames, filenames) in os.walk("./data"):#../patents data
#         for file in filenames:
#     #         files.append(file)
#     #         print(file)
#             with open("./data/"+file , "rb") as f:
#                 html = f.read()
#             soup = BeautifulSoup(html,"lxml")
#             all_ps = soup.findAll("p")
#             if all_ps:
#                 for p in all_ps:
#                     text = p.getText(strip=True)

#                     html = text
#                     # regix replace words with tag
#                     # for each word found save keywords_pargraphs
#     #                     for word in keywords:
#     #                         if
#                     flag = False
#                     for w in keywords:
#                         if re.search(w.ch_word, html):
#                             flag = True
#                             html = re.sub(w.ch_word,'<mark>'+w.ch_word+"</mark>", html)
#     #                 print(text)
#                             print(html)
#                     obj = Pargraph(text=text,html=html,domain_id=1)
#                     db.session.add(obj)
#                     db.session.flush()
#                     db.session.refresh(obj)
#                     p_id = obj.id
#                     db.session.commit()
#                     if flag:
#                         obj = Keyword_Pargraph(pargraph_id=p_id,keyword_id=1)
#                         db.session.add(obj)
#                         db.session.commit()
#     #                 print('-'*30)
#                     # save pargraph

#         break
# except:
#     db.session.rollback()
#     raise
# finally:
#     db.session.close()

# %%
# r = re.search('bar', "hi  im bar")
# if r :
#     print(r)

# %%
def index_data(domain_id):
    keywords = Keyword.query.all()
    for (dirpath, dirnames, filenames) in os.walk("./data/"+str(domain_id)):#../patents data
        for file in filenames:
            with open("./data/"+str(domain_id)+"/"+file , "rb") as f:
                html2 = f.read()
                soup = BeautifulSoup(html2,"lxml")
                all_ps = soup.findAll("p")
                if all_ps:
                    for p in all_ps:

                        text = p.getText(strip=True)

    #                     print(p)
                        if text:
    #                         print(text)

                            html = text

                            flag = False
                            keywords_in_paragraph = []
                            for w in keywords:
                                if re.search(w.ch_word, html):
                                    flag = True
                                    keywords_in_paragraph.append(w.id)
                                    html = re.sub(w.ch_word,'<mark>'+w.ch_word+"</mark>", html)
                                    print(html)

                            p_id = None
#                             print(domain_id)
#                             print(file)
#                             print(text)
#                             print(html)

                            print('-'*30)
#                             try:
#                                 obj = Pargraph.query.filter_by(text = text,file_name=file,domain_id=domain_id).one()
#                                 obj.text=text
#                                 obj.html=html
#                                 p_id = obj.id
#     #                             db.session.commit()
#                             except Exception as e:
                            obj = Pargraph(text=text,html=html,domain_id=domain_id,file_name=file)
                            db.session.add(obj)
                            db.session.flush()
                            db.session.refresh(obj)
                            p_id = obj.id
                            db.session.commit()


                            if flag:
                                for keyword_id in keywords_in_paragraph:
                                    try:
                                        Keyword_Pargraph.query.filter_by(pargraph_id=p_id,keyword_id=keyword_id).one()
                                    except Exception as e:
                                        obj = Keyword_Pargraph(pargraph_id=p_id,keyword_id=keyword_id)
                                        db.session.add(obj)
                                        db.session.commit()

        break

# %%
def index_all_data():
    start_time = time.time()
    domains = Domain.query.all()
    for d in domains:
        print(d.url)
#         try:
        index_data(d.id)
#         except:
#             db.session.rollback()
#             raise
#         finally:
#             db.session.close() 
    
    end_time = time.time() - start_time
    print("finished in ({}) s".format(end_time))

index_all_data()
# Out:
# http://xb.81.cn
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 新兵连的故<mark>事</mark> | 我的班长超厉害！
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 法律顾问：北京荣德律师<mark>事</mark>务所
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 晚会现场灯光璀璨，掌声雷动，喜气洋洋。伴随着激昂的音乐和深情的解说，大屏幕上开始播放“甘于奉献、矢志打赢的雪域车王”孙伶福的<mark>事</mark>迹短片，一名汽车连长的风采呈现在官兵面前。颁奖晚会前，该旅宣传科的同志深入8名“荣誉战士”所在单位进行采访，挖掘了他们背后的感人故<mark>事</mark>，将每个典型的先进<mark>事</mark>迹制作成3分钟左右的短片。
# ------------------------------
# ------------------------------
# 看着感人的画面，听着铿锵的颁奖辞，官兵中爆发出阵阵如潮掌声。旅长贺胜介绍说，此次评选的“荣誉战士”，本着“突出岗位特点、突出工作成绩、突出示范带动”的原则，是经千余官兵代表海选投票和严格审查产生的，<mark>事</mark>迹过硬，具有先进性和代表性，达到“以文化人，以武育人”的目的。在颁奖晚会上，官兵们通过观看“荣誉战士”<mark>事</mark>迹短片和聆听颁奖辞，深入学习“荣誉战士”先进<mark>事</mark>迹，鲜明立起“新一代革命军人”的好样子。
# ------------------------------
# ------------------------------
# ------------------------------
# 军<mark>事</mark>医学科学院完成寨卡病毒全基因组序列测定
# ------------------------------
# ------------------------------
# 解放军报北京2月23日电 庄颖娜、特约记者沈基飞报道：记者今天从军<mark>事</mark>医学科学院获悉，春节期间，我国广东省出现寨卡病毒输入性感染病例后，该院微生物流行病研究所迅即启动应急工作机制，与广州市第八人民医院、出入境检验检疫系统相关单位密切合作，在获得患者临床标本后，于2月21日直接从尿液中获得病毒全基因组序列。
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 一个国家或民族，没有一种强烈的尚武精神，即便是经济繁荣、富甲天下，这个国家或民族也不能获得真正的尊严和他人的尊重。纵观人类历史，尚武好勇的精神，加上开放进取的胸怀，还有理性前瞻的战略眼光，永远能战胜萎靡不振、柔弱保守、目光短浅。没有精神和灵魂的支撑，人何以立？国何以立？放眼世界，凡是创造辉煌历史的国家，大多都是尚武之国。近五百年世界史，西方列强之所以“绝出前古，横被全球”，不单是凭借着现代贸易强国的，而是始终有着强大的军<mark>事</mark>力量作支撑。
# ------------------------------
时机把握不准，不能因地制宜做好思想引导工作，尤其是在演习演练、野外驻训、军<mark>事</mark>比武等重大军<mark>事</mark>活动中，显露出跟不上去、用不上劲的突出问题。三是教育“包装形式”与“客户追求”的供需错位。部分政工干部施教理念陈旧化严重，填鸭式、灌输式、权威式教育模式依然占据大块“市场份额”，启发式、互动式、研讨式教育凤毛麟角；少数施教者以“鸵鸟心态”看待新情况新问题，对网络的负面认识过于片面化、绝对化、放大化，因习惯于传统方法不想用网、担心发生失泄密不敢用网、怕增加工作量不愿用网，对“互联网+教育”“大数据+教育”的新兴模式闭明塞聪；有的对网络媒介运用仍处于低层次徘徊，政工网仅限用于信息转载、知识浏览、资料查询，运用网络媒介激发官兵参与教育积极性的方法手段不多不新；有的单位官兵自主学习娱乐多，组织开展官兵集体交流互动、参观实践等活动少，思想政治教育方法手段乏善可陈。
# ------------------------------
# ------------------------------
# 一、提升施教能力，调整思想政治教育“产业结构”。作为思想政治教育产品的供给主体，施教者是教育质量的决定性因素。重拾思想政治教育价值，要从提升施教队伍能力素质这个源头出发，着力提高供给质量。一是练好“知情功”。没有调查就没有发言权，精准掌握需求主体的所思所想、所期所盼、所忧所患是确保教育取得实效的关键所在。要确实转变让骨干汇报的务虚作风，撸起袖子、放下架子、沉下身子融入官兵察实情、实察情，切实摸准不同基础、不同岗位、不同层次官兵的现实思想反映，为因材施教、有的放矢提供精准的数据支撑。二是练好“说理功”。“<mark>事</mark>有必至，理有固然”。成功的思想教育，应该“三分关乎于情，七分叙之于理”。要从讲道理就是“空洞说教”的观念中转变过来，将情理有机结合，理直气壮讲大道理、抽丝剥茧驳歪道理、润物无声叙实道理，使战士听得进、信得过、很受用。三是练好“笃行功”。“欲实据而有，要在笃於行”。施教者既要注重“言传供给”，更要注重“身教供给”，潜移默化地使教育在官兵心中留下烙印。要在生活点滴中，注重发挥“行”的引导力，主动践言践行，做到自己和别人一个样、说得和做得一个样、课上和课下一个样、人前和人后一个样，不断强化教育的影响力和延伸度。
# ------------------------------
# ------------------------------
# 三、创新方法手段，调整思想政治教育“流通结构”。施教者要结合官兵文化程度、人生阅历、兵龄长短、家庭背景等特点，做好一人一<mark>事</mark>“分餐式”的思想引导，在思想研究上定准方向、在手段方式上找准穴位、在实施方法上敲准鼓点，对症下药、量体裁衣，真正把“群发”的过去式变成“自发”的进行时。二要“区间调控”更要“相机调控”。当前，抱着手机、摸着键盘、泡着网络成长起来的90后官兵成为部队的主体，他们思维活、想法多，思想波动频繁，为新时期思想政治教育带来了一定的挑战。施教者应结合时代的发展和兵员的多元及时调整教育理念，增加随机教育比重，相好时机从情感波动点、从情趣共鸣点、从形势变化点切入，在遇有国内外重大<mark>事</mark>件、部队重大情况和执行重大任务，施教者应因势利导第一时间打好预防针，增强官兵思想免疫力，确保始终占据教育阵地主动权。三要鼓励“听客”更要鼓励“创客”。实践告诉我们，群众的力量不可低估。施教者可以从官兵这个群体中挖掘智慧和力量，适时将舞台让给官兵、话筒递给官兵，变一人讲为大家谈，将广大官兵眼中<mark>事</mark>、身边人、实在理融入课堂、进入思想，使大家在大众评论和现场交锋中明辨是非，构建人人都是教育者、个个又是施教者的“众筹”“众创”教育新格局。
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 纲要在基层工作的组织突出强调了机关作为一线指挥部统筹规划的重要性。在开展工作中，机关各部门要各司其职，突出一个“统”字，形成指导和服务基层的整体合力。一要统好思想。基层是军队的源头活水，作为机关要摆正位置、校准方向，自觉强化“深入基层”的思想，严格落实下连当兵、蹲连住班制度，带着感情当兵，扛着使命下连；强化“服务基层”思想，发挥好“ 传经、送暖、帮急”的作用，把基层反映强烈的问题解决在当下、解决在本级；强化“信任基层”的思想，要将基层“配餐”与基层“点餐”结合起来，将权力下放，避免独权揽权，让真正了解基层的大胆管理基层。二要统好工作。基层的人员分配导致其<mark>事</mark>物繁多的必然性，所以机关要将工作做在前头，对待基层工作要多些统筹，少些折腾。在规范抓建基层的秩序上用力，优化下行指导方式方法，减轻基层压力，让方案计划贴紧中心任务、接拢基层地气；在提高抓建基层的能力上用力，按照《纲要》要求，严格实行机关干部岗位轮换和代职锻炼制度，通过院校培养、岗位集训、业务比武等形式不断加强自身能力建设；在转变抓建基层的作风上用力，将“线头搓细”交给基层。要整合各类业务工作，变“单独组织”为“联合下放”；整合检查督导，变“多头牵线”为“综合考察”；整合比武竞赛，变“专项竞技”为“综合考评”。三要统好人才。在工作中要坚持优秀人才向基层输送，在干部选拔、人才培养、队伍建设方面持续用力，强壮基层的“筋骨”，提高其“造血功能”“免疫功能”“排毒功能”。
# ------------------------------
# ------------------------------
# 机关因基层存在并发挥作用。在工作中要将基层建设作为本职要务来抓，保证中心工作居中，主要业务主抓，瞄准基层建设这一靶心不放松。一要把握强固基层之本。《纲要》指出：把军<mark>事</mark>训练作为部队经常性中心工作和提高战斗力的根本途径，坚持按纲施训、依法施训。在机关指导基层实践中，要坚持将军<mark>事</mark>训练作为强固基层的核心要义来抓，防止力量游离于打仗之外。要端正聚战的工作指导上持续用力。从实际情况来看，当前一些基层主官受政绩观和安全因素影响，战斗力标准存在偏航、跑调的现象，所以在工作中，要引领基层强化唯战的工作指导，让众多的之一服务于战斗力这个唯一，用战斗力标准筹划、推进、检验基层发展；要在抓住聚战的用人导向上持续用力。真正用打仗人的标准选人用人，加强军官作战理论、军<mark>事</mark>谋略、指挥技能训练，不断优化干部军<mark>事</mark>素质考核认证方法；要在浓厚聚战的尚武氛围上持续用力。从纠正训风、考风、演风入手，增强训练险度和难度，按实战环境设置条件，按作战进程组织演训，把实战化贯穿渗透于军<mark>事</mark>训练全过程各领域，向和平积习开刀喊打。二要务尽抓建基层之职。建设基层犹如插秧苗，要保持躬身前行。要俯下身子、撩开膀子、撸起袖子，深入基层一线了解基层建设存在的突出问题、部队发展存在的突出矛盾、官兵心中存在的突出企盼。既要提要求，又要给条件；既注重结果，又关注过程。多些减法，少些加法；多些“雪中送炭”，少些“火上浇油”；多些身心深入，少些走马观花。建设基层犹如燕搭窝，要注重常抓实效，避免时断时续、时紧时松，始终保持抓建基层的热情不减、动力不减。要紧贴《纲要》精神要求，注重全面搞建设、扎实打基础、反复抓落实，形成有利于基层发展的长效机制。三要履好服务基层之责。这就要求机关部门要始终牢记服务基层的核心职责使命所在，校正“准星”，瞄准“靶心”开展工作，把基层建设作为第一要务，把官兵关切作为第一信号、把官兵满意作为第一标准。要少说“办不了”，多想“怎么办”；少想“以后说”，多说“尽快办”，坚持要<mark>事</mark>不轻视、急<mark>事</mark>不拖延、难<mark>事</mark>不推诿，当好基层的“协理员”、“服务生”。
# ------------------------------
# ------------------------------
# 机关要严格按照法定职责权限抓好工作，努力实现从单纯依靠行政命令的做法向依法行政的根本性转变，从突击式、运动式抓工作的方式向按条令条例办<mark>事</mark>的根本性转变。一要理顺关系，严守按纲抓建之法。法规制度是基层经验的凝结和升华，但在实践中，有些基层主官认为“条例不如惯例、法规不如家规。红头不如口头”，削减了法规的执行力度，权压法、话代法的现象依然存在。因此要强化法治理念，真正将法规制度精神要求入心入行，纠正脱纲离谱的偏向；提高法治能力，坚决革除人治思维、特权思维和专职思维。机关干部带头学法用法维法，纠正有法不依的偏向；营造法治氛围，机关带头抓守法导向，通过建强队伍抓执法力量、建章立制抓依法督导、优化环境抓遵法氛围，营造良好法治生态。二要树好形象，严守正风肃纪之法。上乃风之源、气之始。机关各部门应该以法度的尺子衡量自己，以严格的标准要求自己，以巨大的勇气改造自己，真正从政治态度上亮明立场、从价值取向上；厘清是非，从立身做人上清楚沾染。坚持离基层越近，离“四风”越远的原则，以原则为镜照照自身抓的如何、自身作风改的如何，真正为基层树立好样子。三要强化内功，严守科学指导之法。坚持用强军目标的核心审视、用能打胜仗的尺子检验，用全面过硬的标准衡量，树立与时代发展和现代战争相适应的观念理念，改进指导方式和工作方法，增强抓建基层质量效益。要多些创新观念，少些惯性思维。随着军<mark>事</mark>改革的不断深入，基层的使命任务和发展特点正发生深刻变化，如果仍然按照“一线平推”“经验主义”的理念，一定会迟滞基层的发展。因此在工作中要树立创新意识，紧密结合不同单位、不同时段、不同环境特点，在贯彻《纲要》、继承传统、实践检验中不断创新方式方法，做好动态分散条件下各项工作；要多些务实观念，少些漂浮作风。在工作中要树立目标意识，综合考虑基层压力、能力、节奏等问题，制订“接地气、有温度”的目标任务。既不能盲从<mark>事</mark>务工作，鼠目寸光，又不能主观臆断，好高骛远，切忌出现“口号喊得响亮、成效少的可怜”“只顾效应，不顾效益”的现象发生，既要“懂绘图”，又要“会施工”，在掌握实情、解决问题、促进工作中发挥好把关定向的作用。
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 爸爸这次考试我又考了第一名，妈妈夸我是爸爸的好女儿，爸爸你就放心吧！我一定不会让你失望的，我一定好好学习，将来向你一样，穿上军装，等你老了，我来替你守着爷爷，守着家。到那个时候你就可以回家了，就可以守着妈妈，这样妈妈就不会一个人上班，送我上学，洗衣服，做饭，晚上一个人偷偷流眼泪了。爸爸告诉你一个<mark>事</mark>情，昨天晚上我看到妈妈又拿着手机一个人在那里哭，我知道妈妈一定是想爸爸了，女儿也想你，可是我不能哭，如果我哭了，妈妈会更伤心，我长大了，我要替爸爸照顾妈妈，做爸爸妈妈的好女儿。
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
#

# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 李磊透过盖在卡车上绿色帆布的缝隙往远处看去，阴沉灰蒙的天空、东倒西歪的树木，都只剩下了模糊的轮廓。他凝视着眼前的威远江支流，它在愤怒、在咆哮，又发狂似的卷起一排排巨浪。那气势，像是被激怒的雄狮在咆哮；像是桀骜的纨绔子弟，因为不顺心的<mark>事</mark>，任着性子在撒野。惊天动地的吼声时起时伏从不间断，似乎它就是引发那山体滑坡的罪魁祸首。
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 在暴风雨中奔跑，这可是一件不平常的<mark>事</mark>。
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 李磊看着脸色像铁一般的连长，低声说：“连长，让我来带吧！你也了解我的，我的军<mark>事</mark>素质可不比你差！我肯定跑得比你还快。”
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 当他们赶到<mark>事</mark>故现场，映入眼帘的是辆遍体鳞伤的灰色面包车，像匹受伤的马奄奄一息地侧躺在那只有四米宽的公路边上。雨刷绵软无力地自动左右摇摆着；发动机发出“呜呜呜”的声音，像是在哭泣。其他人还没来得及反应，连长早已以百米冲刺的速度跑了过去。
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 连长亲切地说：“兄弟，不要担心，你的孩子肯定没<mark>事</mark>！你流这么多血，得先赶紧包扎！”其实，他们并非专业的医务人员，然而凭借着丰富的处理训练伤的经验，他们对驾驶员进行了有效的急救。
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------
# 中国军网-西部战区“军中寻缘”相亲服务升级启<mark>事</mark>
# ------------------------------
# ------------------------------
# 法律顾问：北京荣德律师<mark>事</mark>务所
# ------------------------------
# ------------------------------
# ------------------------------
# http://db.81.cn
# http://nb.81.cn
# finished in (4.662850856781006) s

# %%
def reindex_data(keyword , keyword_id):
    all_ps = Pargraph.query.all()
    if all_ps:
        for p in all_ps:
            html = p.html
            flag = False
            if re.search(keyword, html):
                flag = True
                html = re.sub(keyword,'<mark>'+keyword+"</mark>", html)
                
            
            if flag:
                p.html = html
                db.session.commit()
                
                try:
                    Keyword_Pargraph.query.filter_by(pargraph_id=p.id,keyword_id=keyword_id).one()
                except Exception as e:
                    obj = Keyword_Pargraph(pargraph_id=p.id,keyword_id=keyword_id)
                    db.session.add(obj)
                    db.session.commit()
def reindex_all_data():
    start_time = time.time()
    keywords = Domain.query.all()
    for w in keywords:
        print(w.en_word)
#         try:
        reindex_data(w.ch_word , w.id)
#         except:
#             db.session.rollback()
#             raise
#         finally:
#             db.session.close() 
    
    end_time = time.time() - start_time
    print("finished in ({}) s".format(end_time))

    
reindex_all_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-aebe32e6fba8> in <module>()
#      37
#      38
# ---> 39 reindex_all_data()
#
# <ipython-input-8-aebe32e6fba8> in reindex_all_data()
#      24     keywords = Domain.query.all()
#      25     for w in keywords:
# ---> 26         print(d.en_word)
#      27 #         try:
#      28         reindex_data(w.ch_word , w.id)
#
# NameError: name 'd' is not defined

# %%
# exist = Keyword_Pargraph.query.filter_by(pargraph_id=1,keyword_id=2)

# %%
# try:
#     exist.one()
# except Exception as e:
#     print(e)

# %%
# dd = Domain.query.all()
# for d in dd:
#     d.url=d.url[:-1]
#     db.session.commit()

# %%
from apscheduler.schedulers.background import BackgroundScheduler
scheduler = BackgroundScheduler()
scheduler.start()

def test():
    print("dsvjnvkjsndkcjsd")
print(scheduler.get_job('crawl_all'))
# scheduler.add_job(test, 'interval',seconds=1,id="crawl_all")
# while True:
#     pass
